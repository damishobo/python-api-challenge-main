# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#print(weather_api_key)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 639

# %%
cities
# Out:
# ['port blair',
#  'butaritari',
#  'ushuaia',
#  'grand river south east',
#  'jamestown',
#  'atuona',
#  'bengkulu',
#  'jiwani',
#  'tabiauea',
#  'rikitea',
#  'puerto ayora',
#  'sabang',
#  'bredasdorp',
#  'georgetown',
#  'hobart',
#  'cockburn town',
#  'quelimane',
#  'pokhara',
#  'chuy',
#  'ereymentau',
#  'busselton',
#  'sao miguel do araguaia',
#  'kapaa',
#  'qaanaaq',
#  'bandarbeyla',
#  'goderich',
#  'klaksvik',
#  'bara',
#  'kodiak',
#  'faanui',
#  'khatanga',
#  'arraial do cabo',
#  'dikson',
#  'ulaangom',
#  'port hedland',
#  'kyshtovka',
#  'tsihombe',
#  'moscow',
#  'mullaitivu',
#  'victoria',
#  'inuvik',
#  'ponta do sol',
#  'saharanpur',
#  'whitehorse',
#  'fairbanks',
#  'sovetskiy',
#  'barrow',
#  'hithadhoo',
#  'bethel',
#  'punta arenas',
#  'east london',
#  'kavieng',
#  'taolanaro',
#  'hermanus',
#  'voh',
#  'agogo',
#  'labrea',
#  'atasu',
#  'esperance',
#  'falealupo',
#  'rocha',
#  'ostrovnoy',
#  'gedo',
#  'cherskiy',
#  'khandyga',
#  'cape town',
#  'mataura',
#  'yellowknife',
#  'cidreira',
#  'lolua',
#  'odienne',
#  'mezen',
#  'banjar',
#  'la libertad',
#  'cabo san lucas',
#  'nikolskoye',
#  'kalemie',
#  'tiksi',
#  'inhambane',
#  'lahij',
#  'port elizabeth',
#  'nizhneyansk',
#  'namatanai',
#  'amderma',
#  'maragogi',
#  'havre-saint-pierre',
#  'belmonte',
#  'caravelas',
#  'sao filipe',
#  'necochea',
#  'san policarpo',
#  'mahebourg',
#  'paidha',
#  'tiznit',
#  'lebu',
#  'tasiilaq',
#  'flagstaff',
#  'honningsvag',
#  'illoqqortoormiut',
#  'sangar',
#  'sompeta',
#  'tonj',
#  'kaitangata',
#  'torbay',
#  'buala',
#  'hervey bay',
#  'pisco',
#  'vaitupu',
#  'vardo',
#  'saldanha',
#  'zyryanovskiy',
#  'saskylakh',
#  'ancud',
#  'new norfolk',
#  'gumia',
#  'biu',
#  'barentsburg',
#  'abu kamal',
#  'progreso',
#  'anuradhapura',
#  'miyako',
#  'williamsburg',
#  'albany',
#  'mar del plata',
#  'pouembout',
#  'lincoln',
#  'maniitsoq',
#  'talakan',
#  'san quintin',
#  'shymkent',
#  'saint anthony',
#  'launceston',
#  'erenhot',
#  'kikwit',
#  'husavik',
#  'waingapu',
#  'vaini',
#  'champasak',
#  'grindavik',
#  'avarua',
#  'koumac',
#  'riyadh',
#  'paragominas',
#  'koson',
#  'grand gaube',
#  'beira',
#  'sao joao da barra',
#  'stochov',
#  'zhelyabovka',
#  'beidao',
#  'tomatlan',
#  'thompson',
#  'bluff',
#  'gongzhuling',
#  'port alfred',
#  'tangwani',
#  'hilo',
#  'najran',
#  'bathsheba',
#  'ribeira grande',
#  'longyearbyen',
#  'pevek',
#  'newport',
#  'gustavo diaz ordaz',
#  'dingle',
#  'kitimat',
#  'tura',
#  'lagoa',
#  'macklin',
#  'puerto escondido',
#  'papar',
#  'mattawa',
#  'banda aceh',
#  'touros',
#  'skovorodino',
#  'acapulco',
#  'praxedis guerrero',
#  'tremedal',
#  'arti',
#  'shitanjing',
#  'xining',
#  'piracuruca',
#  'roald',
#  'denpasar',
#  'katete',
#  'malente',
#  'broome',
#  'hami',
#  'gangotri',
#  'itarema',
#  'valparaiso',
#  'rio gallegos',
#  'kawalu',
#  'chokurdakh',
#  'cotonou',
#  'belushya guba',
#  'san jose',
#  'aklavik',
#  'norman wells',
#  'bela vista de goias',
#  'cabedelo',
#  'ngukurr',
#  'kruisfontein',
#  'nicoya',
#  'te anau',
#  'le port',
#  'torquay',
#  'marawi',
#  'beringovskiy',
#  'gunjur',
#  'merauke',
#  'saleaula',
#  'kamenskoye',
#  'ushtobe',
#  'hualmay',
#  'louisbourg',
#  'saint-ambroise',
#  'mount isa',
#  'castro',
#  'ramotswa',
#  'anadyr',
#  'san andres',
#  'eenhana',
#  'porbandar',
#  'coihaique',
#  'mentok',
#  'salalah',
#  'ozgon',
#  'kogon',
#  'brigantine',
#  'mufumbwe',
#  'kamenka',
#  'mabaruma',
#  'narsaq',
#  'ugoofaaru',
#  'itaituba',
#  'bubaque',
#  'saint george',
#  'sentyabrskiy',
#  'ursulo galvan',
#  'mandalgovi',
#  'healdsburg',
#  'murgab',
#  'coffs harbour',
#  'xacmaz',
#  'neiafu',
#  'ulu-telyak',
#  'sorong',
#  'dudinka',
#  'suleja',
#  'airai',
#  'dunedin',
#  'bozova',
#  'teluk intan',
#  'tuatapere',
#  'deputatskiy',
#  'ahipara',
#  'grand-santi',
#  'mariental',
#  'labuhan',
#  'carnarvon',
#  'skjervoy',
#  'longlac',
#  'clyde river',
#  'dekalb',
#  'zasheyek',
#  'diffa',
#  'ifanadiana',
#  'bardiyah',
#  'kazalinsk',
#  'camacupa',
#  'samusu',
#  'northwich',
#  'kaeo',
#  'palabuhanratu',
#  'madhipura',
#  'pouebo',
#  'grao mogol',
#  'itoman',
#  'half moon bay',
#  'ilulissat',
#  'phek',
#  'emba',
#  'puerto carreno',
#  'olafsvik',
#  'viedma',
#  'popondetta',
#  'upernavik',
#  'bati',
#  'alofi',
#  'balkhash',
#  'dalmatovo',
#  'damaturu',
#  'provideniya',
#  'sirnak',
#  'mocuba',
#  'makakilo city',
#  'moron',
#  'hovd',
#  'qandahar',
#  'celestun',
#  'daye',
#  'pskov',
#  'narrabri',
#  'redmond',
#  'guerrero negro',
#  'sarh',
#  'tuktoyaktuk',
#  'muros',
#  'am timan',
#  'glendive',
#  'san bartolome',
#  'faya',
#  'cluj-napoca',
#  'bonavista',
#  'nhulunbuy',
#  'seoul',
#  'comodoro rivadavia',
#  'khalkhal',
#  'fergus falls',
#  'hay river',
#  'pacific grove',
#  'strezhevoy',
#  'fort saint james',
#  'kamaishi',
#  'geraldton',
#  'saint-augustin',
#  'luderitz',
#  'noshiro',
#  'rudbar',
#  'magdagachi',
#  'atar',
#  'el cobre',
#  'umm kaddadah',
#  'bud',
#  'salta',
#  'warwick',
#  'tabou',
#  'naze',
#  'paamiut',
#  'gerash',
#  'lata',
#  'jiazi',
#  'sal rei',
#  'san patricio',
#  'carauari',
#  'moerai',
#  'bereda',
#  'gainesville',
#  'severo-kurilsk',
#  'slave lake',
#  'panaba',
#  'presidencia roque saenz pena',
#  'flin flon',
#  'szprotawa',
#  'kachikau',
#  'ouallam',
#  'nome',
#  'horki',
#  'jalu',
#  'mago',
#  'bakchar',
#  'pauini',
#  'okhotsk',
#  'general bravo',
#  'guararapes',
#  'alyangula',
#  'lavrentiya',
#  'westport',
#  'twin falls',
#  'sistranda',
#  'lucapa',
#  'bria',
#  'buraydah',
#  'huarmey',
#  'port-gentil',
#  'gat',
#  'santa ana',
#  'north bend',
#  'mecca',
#  'tera',
#  'severobaykalsk',
#  'sokoni',
#  'puerto cabello',
#  'seydi',
#  'tibiao',
#  'komsomolskiy',
#  'ibra',
#  'chilliwack',
#  'broken hill',
#  'dakar',
#  'yumen',
#  'sakakah',
#  'taltal',
#  'hasaki',
#  'bambous virieux',
#  'mocambique',
#  'san cristobal',
#  'palizada',
#  'alta floresta',
#  'samana',
#  'yar-sale',
#  'port lincoln',
#  'sitka',
#  'praia da vitoria',
#  'nanortalik',
#  'krapkowice',
#  'megara',
#  'tumannyy',
#  'ternate',
#  'mys shmidta',
#  'vila velha',
#  'hornepayne',
#  'sarahan',
#  'namibe',
#  'adrar',
#  'auki',
#  'kribi',
#  'avera',
#  'ilhabela',
#  'jinchang',
#  'chazuta',
#  'nerang',
#  'rawson',
#  'beatrice',
#  'krotoszyn',
#  'isangel',
#  'padang',
#  'fort nelson',
#  'sibolga',
#  'coolum beach',
#  'callaway',
#  'srisailam',
#  'bac lieu',
#  'calabazar de sagua',
#  'zachagansk',
#  'saint-philippe',
#  'mufulira',
#  'jacqueville',
#  'sinnamary',
#  'kununurra',
#  'richards bay',
#  'podbelsk',
#  'karratha',
#  'zarechnyy',
#  'toliary',
#  'zambezi',
#  'tongliao',
#  'ca mau',
#  'guarapuava',
#  'marienburg',
#  'hofn',
#  'taoudenni',
#  'honiara',
#  'aranos',
#  'san angelo',
#  'qianan',
#  'shimoda',
#  'gornopravdinsk',
#  'sioux lookout',
#  'maun',
#  'vila franca do campo',
#  'simao',
#  'jijiga',
#  'cancuc',
#  'sotnikovo',
#  'sisimiut',
#  'pau',
#  'bourail',
#  'ukiah',
#  'hobyo',
#  'hamilton',
#  'codrington',
#  'talnakh',
#  'cody',
#  'kyabram',
#  'amapa',
#  'rungata',
#  'scottsbluff',
#  'zholymbet',
#  'maceio',
#  'mackay',
#  'riviere-au-renard',
#  'santa cruz',
#  'karlshamn',
#  'atambua',
#  'kudahuvadhoo',
#  'indramayu',
#  'livno',
#  'saint-michel-des-saints',
#  'verkhnyaya inta',
#  'george town',
#  'cayenne',
#  'college',
#  'guilin',
#  'kahului',
#  'mancio lima',
#  'balkanabat',
#  'mahanoro',
#  'kashirskoye',
#  'ruatoria',
#  'xichang',
#  'dinsor',
#  'vuktyl',
#  'piacabucu',
#  'clarence town',
#  'contai',
#  'kemijarvi',
#  'gorin',
#  'mercedes',
#  'seymchan',
#  'pontianak',
#  'porto novo',
#  'yaan',
#  'marv dasht',
#  'formoso do araguaia',
#  'henties bay',
#  'afsin',
#  'agadir',
#  'guozhen',
#  'pascagoula',
#  'majene',
#  'yulara',
#  'billings',
#  'las vegas',
#  'port macquarie',
#  'lethem',
#  'watsa',
#  'griffith',
#  'tabas',
#  'bani walid',
#  'yucca valley',
#  'strelka',
#  'brae',
#  'pochutla',
#  'xushan',
#  'borogontsy',
#  'sinop',
#  'orsha',
#  'erdenet',
#  'katsuura',
#  'attawapiskat',
#  'iskateley',
#  'ishigaki',
#  'palmer',
#  'mandera',
#  'tigil',
#  'darnah',
#  'hambantota',
#  'jeffersontown',
#  'nantucket',
#  'laguna',
#  'akyab',
#  'usakos',
#  'constitucion',
#  'eureka',
#  'northam',
#  'coquimbo',
#  'bandundu',
#  'shuangcheng',
#  'tautira',
#  'sur',
#  'altay',
#  'tamworth',
#  'ponta delgada',
#  'linxia',
#  'altamont',
#  'george',
#  'kuznechikha',
#  'mananjary',
#  'qostanay',
#  'faxinal',
#  'cazaje',
#  'kutum',
#  'awbari',
#  'shaunavon',
#  'chicama',
#  'mahibadhoo',
#  'heishan',
#  'guiratinga',
#  'dandong',
#  'hirado',
#  'lorengau',
#  'maarianhamina',
#  'buariki',
#  'mumford',
#  'ferme-neuve',
#  'chute-aux-outardes',
#  'rawannawi',
#  'dwarahat',
#  'la ronge',
#  'rio grande',
#  'west wendover',
#  'llanes',
#  'gazli',
#  'camacha',
#  'niksic',
#  'fukue',
#  'volodarka',
#  'mehamn',
#  'yeppoon',
#  'zhuanghe',
#  'waverly',
#  'torrington',
#  'susanville',
#  'holguin',
#  'khani',
#  'hasanabad',
#  'sinkat',
#  'marfino',
#  'olinda',
#  'vostok',
#  'sagar',
#  'phalaborwa',
#  'pemba',
#  'bunia',
#  'matagami',
#  'srednekolymsk',
#  'coralville',
#  'antofagasta',
#  'kalmunai',
#  'kommunisticheskiy',
#  'jarjis',
#  'berdigestyakh',
#  'otjimbingwe',
#  'calama',
#  'zapolyarnyy',
#  'karamay',
#  'shunyi',
#  'sechura',
#  'itupiranga',
#  'lompoc',
#  'burgeo',
#  'barcelos',
#  'quimper',
#  'khormuj',
#  'helmsdale',
#  'rio tuba',
#  'sabha']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city 

    
    # # Log the url, record, and set numbers
    import json
    import os
    
    response = requests.get(city_url).json()
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # print(json.dumps(response, indent=4, sort_keys=True))
    # # Add 1 to the record count
    record_count += 1

    # # Run an API request for each of the cities
    
    
    #     # Parse the JSON and retrieve data


# filepath = os.path.join("..", "python-api-challenge-main", "")

    city_weather = response 
    # print(city_weather)
    

    #     # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    try:
        city_lat = city_weather["coord"]["lat"] 
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

    #     # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port blair
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | bengkulu
# Processing Record 8 of Set 1 | jiwani
# Processing Record 9 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | sabang
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | cockburn town
# Processing Record 17 of Set 1 | quelimane
# Processing Record 18 of Set 1 | pokhara
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | ereymentau
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | sao miguel do araguaia
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | bandarbeyla
# Processing Record 26 of Set 1 | goderich
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | bara
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | ulaangom
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | kyshtovka
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | moscow
# Processing Record 39 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | inuvik
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | saharanpur
# Processing Record 44 of Set 1 | whitehorse
# Processing Record 45 of Set 1 | fairbanks
# Processing Record 46 of Set 1 | sovetskiy
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 0 of Set 2 | east london
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | voh
# Processing Record 5 of Set 2 | agogo
# Processing Record 6 of Set 2 | labrea
# Processing Record 7 of Set 2 | atasu
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 2 | rocha
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | gedo
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 2 | odienne
# Processing Record 21 of Set 2 | mezen
# Processing Record 22 of Set 2 | banjar
# Processing Record 23 of Set 2 | la libertad
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | kalemie
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | inhambane
# Processing Record 29 of Set 2 | lahij
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | namatanai
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | havre-saint-pierre
# Processing Record 36 of Set 2 | belmonte
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | necochea
# Processing Record 40 of Set 2 | san policarpo
# Processing Record 41 of Set 2 | mahebourg
# Processing Record 42 of Set 2 | paidha
# Processing Record 43 of Set 2 | tiznit
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | flagstaff
# Processing Record 47 of Set 2 | honningsvag
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | sangar
# Processing Record 0 of Set 3 | sompeta
# Processing Record 1 of Set 3 | tonj
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | hervey bay
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | vardo
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | zyryanovskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | gumia
# Processing Record 15 of Set 3 | biu
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | abu kamal
# Processing Record 18 of Set 3 | progreso
# Processing Record 19 of Set 3 | anuradhapura
# Processing Record 20 of Set 3 | miyako
# Processing Record 21 of Set 3 | williamsburg
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | pouembout
# Processing Record 25 of Set 3 | lincoln
# Processing Record 26 of Set 3 | maniitsoq
# Processing Record 27 of Set 3 | talakan
# Processing Record 28 of Set 3 | san quintin
# Processing Record 29 of Set 3 | shymkent
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | launceston
# Processing Record 32 of Set 3 | erenhot
# Processing Record 33 of Set 3 | kikwit
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | waingapu
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | champasak
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | koumac
# Processing Record 41 of Set 3 | riyadh
# Processing Record 42 of Set 3 | paragominas
# Processing Record 43 of Set 3 | koson
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | beira
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | stochov
# Processing Record 48 of Set 3 | zhelyabovka
# Processing Record 49 of Set 3 | beidao
# Processing Record 0 of Set 4 | tomatlan
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | gongzhuling
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | tangwani
# Processing Record 6 of Set 4 | hilo
# Processing Record 7 of Set 4 | najran
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | newport
# Processing Record 13 of Set 4 | gustavo diaz ordaz
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | kitimat
# Processing Record 16 of Set 4 | tura
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | macklin
# Processing Record 19 of Set 4 | puerto escondido
# Processing Record 20 of Set 4 | papar
# Processing Record 21 of Set 4 | mattawa
# Processing Record 22 of Set 4 | banda aceh
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | skovorodino
# Processing Record 25 of Set 4 | acapulco
# Processing Record 26 of Set 4 | praxedis guerrero
# Processing Record 27 of Set 4 | tremedal
# Processing Record 28 of Set 4 | arti
# Processing Record 29 of Set 4 | shitanjing
# Processing Record 30 of Set 4 | xining
# Processing Record 31 of Set 4 | piracuruca
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | denpasar
# Processing Record 34 of Set 4 | katete
# Processing Record 35 of Set 4 | malente
# Processing Record 36 of Set 4 | broome
# Processing Record 37 of Set 4 | hami
# Processing Record 38 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 4 | itarema
# Processing Record 40 of Set 4 | valparaiso
# Processing Record 41 of Set 4 | rio gallegos
# Processing Record 42 of Set 4 | kawalu
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | cotonou
# Processing Record 45 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 4 | san jose
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | norman wells
# Processing Record 49 of Set 4 | bela vista de goias
# Processing Record 0 of Set 5 | cabedelo
# Processing Record 1 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | nicoya
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | le port
# Processing Record 6 of Set 5 | torquay
# Processing Record 7 of Set 5 | marawi
# Processing Record 8 of Set 5 | beringovskiy
# Processing Record 9 of Set 5 | gunjur
# Processing Record 10 of Set 5 | merauke
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 5 | ushtobe
# Processing Record 14 of Set 5 | hualmay
# Processing Record 15 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint-ambroise
# Processing Record 17 of Set 5 | mount isa
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | ramotswa
# Processing Record 20 of Set 5 | anadyr
# Processing Record 21 of Set 5 | san andres
# Processing Record 22 of Set 5 | eenhana
# Processing Record 23 of Set 5 | porbandar
# Processing Record 24 of Set 5 | coihaique
# Processing Record 25 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 5 | kogon
# Processing Record 29 of Set 5 | brigantine
# Processing Record 30 of Set 5 | mufumbwe
# Processing Record 31 of Set 5 | kamenka
# Processing Record 32 of Set 5 | mabaruma
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | ugoofaaru
# Processing Record 35 of Set 5 | itaituba
# Processing Record 36 of Set 5 | bubaque
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | ursulo galvan
# Processing Record 40 of Set 5 | mandalgovi
# Processing Record 41 of Set 5 | healdsburg
# Processing Record 42 of Set 5 | murgab
# Processing Record 43 of Set 5 | coffs harbour
# Processing Record 44 of Set 5 | xacmaz
# Processing Record 45 of Set 5 | neiafu
# Processing Record 46 of Set 5 | ulu-telyak
# Processing Record 47 of Set 5 | sorong
# Processing Record 48 of Set 5 | dudinka
# Processing Record 49 of Set 5 | suleja
# Processing Record 0 of Set 6 | airai
# Processing Record 1 of Set 6 | dunedin
# Processing Record 2 of Set 6 | bozova
# Processing Record 3 of Set 6 | teluk intan
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | deputatskiy
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | grand-santi
# Processing Record 8 of Set 6 | mariental
# Processing Record 9 of Set 6 | labuhan
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | skjervoy
# Processing Record 12 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | dekalb
# Processing Record 15 of Set 6 | zasheyek
# Processing Record 16 of Set 6 | diffa
# Processing Record 17 of Set 6 | ifanadiana
# Processing Record 18 of Set 6 | bardiyah
# Processing Record 19 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 6 | camacupa
# Processing Record 21 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 6 | northwich
# Processing Record 23 of Set 6 | kaeo
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | madhipura
# Processing Record 26 of Set 6 | pouebo
# Processing Record 27 of Set 6 | grao mogol
# Processing Record 28 of Set 6 | itoman
# Processing Record 29 of Set 6 | half moon bay
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | phek
# Processing Record 32 of Set 6 | emba
# Processing Record 33 of Set 6 | puerto carreno
# Processing Record 34 of Set 6 | olafsvik
# Processing Record 35 of Set 6 | viedma
# Processing Record 36 of Set 6 | popondetta
# Processing Record 37 of Set 6 | upernavik
# Processing Record 38 of Set 6 | bati
# Processing Record 39 of Set 6 | alofi
# Processing Record 40 of Set 6 | balkhash
# Processing Record 41 of Set 6 | dalmatovo
# Processing Record 42 of Set 6 | damaturu
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | sirnak
# Processing Record 45 of Set 6 | mocuba
# Processing Record 46 of Set 6 | makakilo city
# Processing Record 47 of Set 6 | moron
# Processing Record 48 of Set 6 | hovd
# Processing Record 49 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 0 of Set 7 | celestun
# Processing Record 1 of Set 7 | daye
# Processing Record 2 of Set 7 | pskov
# Processing Record 3 of Set 7 | narrabri
# Processing Record 4 of Set 7 | redmond
# Processing Record 5 of Set 7 | guerrero negro
# Processing Record 6 of Set 7 | sarh
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | muros
# Processing Record 9 of Set 7 | am timan
# Processing Record 10 of Set 7 | glendive
# Processing Record 11 of Set 7 | san bartolome
# Processing Record 12 of Set 7 | faya
# Processing Record 13 of Set 7 | cluj-napoca
# Processing Record 14 of Set 7 | bonavista
# Processing Record 15 of Set 7 | nhulunbuy
# Processing Record 16 of Set 7 | seoul
# Processing Record 17 of Set 7 | comodoro rivadavia
# Processing Record 18 of Set 7 | khalkhal
# Processing Record 19 of Set 7 | fergus falls
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | pacific grove
# Processing Record 22 of Set 7 | strezhevoy
# Processing Record 23 of Set 7 | fort saint james
# Processing Record 24 of Set 7 | kamaishi
# Processing Record 25 of Set 7 | geraldton
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | noshiro
# Processing Record 29 of Set 7 | rudbar
# Processing Record 30 of Set 7 | magdagachi
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | el cobre
# Processing Record 33 of Set 7 | umm kaddadah
# Processing Record 34 of Set 7 | bud
# Processing Record 35 of Set 7 | salta
# Processing Record 36 of Set 7 | warwick
# Processing Record 37 of Set 7 | tabou
# Processing Record 38 of Set 7 | naze
# Processing Record 39 of Set 7 | paamiut
# Processing Record 40 of Set 7 | gerash
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | jiazi
# Processing Record 43 of Set 7 | sal rei
# Processing Record 44 of Set 7 | san patricio
# Processing Record 45 of Set 7 | carauari
# Processing Record 46 of Set 7 | moerai
# Processing Record 47 of Set 7 | bereda
# Processing Record 48 of Set 7 | gainesville
# Processing Record 49 of Set 7 | severo-kurilsk
# Processing Record 0 of Set 8 | slave lake
# Processing Record 1 of Set 8 | panaba
# Processing Record 2 of Set 8 | presidencia roque saenz pena
# Processing Record 3 of Set 8 | flin flon
# Processing Record 4 of Set 8 | szprotawa
# Processing Record 5 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 6 of Set 8 | ouallam
# Processing Record 7 of Set 8 | nome
# Processing Record 8 of Set 8 | horki
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | mago
# Processing Record 11 of Set 8 | bakchar
# Processing Record 12 of Set 8 | pauini
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | general bravo
# Processing Record 15 of Set 8 | guararapes
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | lavrentiya
# Processing Record 18 of Set 8 | westport
# Processing Record 19 of Set 8 | twin falls
# Processing Record 20 of Set 8 | sistranda
# Processing Record 21 of Set 8 | lucapa
# Processing Record 22 of Set 8 | bria
# Processing Record 23 of Set 8 | buraydah
# Processing Record 24 of Set 8 | huarmey
# Processing Record 25 of Set 8 | port-gentil
# Processing Record 26 of Set 8 | gat
# Processing Record 27 of Set 8 | santa ana
# Processing Record 28 of Set 8 | north bend
# Processing Record 29 of Set 8 | mecca
# Processing Record 30 of Set 8 | tera
# Processing Record 31 of Set 8 | severobaykalsk
# Processing Record 32 of Set 8 | sokoni
# Processing Record 33 of Set 8 | puerto cabello
# Processing Record 34 of Set 8 | seydi
# Processing Record 35 of Set 8 | tibiao
# Processing Record 36 of Set 8 | komsomolskiy
# Processing Record 37 of Set 8 | ibra
# Processing Record 38 of Set 8 | chilliwack
# Processing Record 39 of Set 8 | broken hill
# Processing Record 40 of Set 8 | dakar
# Processing Record 41 of Set 8 | yumen
# Processing Record 42 of Set 8 | sakakah
# Processing Record 43 of Set 8 | taltal
# Processing Record 44 of Set 8 | hasaki
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | palizada
# Processing Record 49 of Set 8 | alta floresta
# Processing Record 0 of Set 9 | samana
# Processing Record 1 of Set 9 | yar-sale
# Processing Record 2 of Set 9 | port lincoln
# Processing Record 3 of Set 9 | sitka
# Processing Record 4 of Set 9 | praia da vitoria
# Processing Record 5 of Set 9 | nanortalik
# Processing Record 6 of Set 9 | krapkowice
# Processing Record 7 of Set 9 | megara
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | ternate
# Processing Record 10 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 9 | vila velha
# Processing Record 12 of Set 9 | hornepayne
# Processing Record 13 of Set 9 | sarahan
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | auki
# Processing Record 17 of Set 9 | kribi
# Processing Record 18 of Set 9 | avera
# Processing Record 19 of Set 9 | ilhabela
# Processing Record 20 of Set 9 | jinchang
# Processing Record 21 of Set 9 | chazuta
# Processing Record 22 of Set 9 | nerang
# Processing Record 23 of Set 9 | rawson
# Processing Record 24 of Set 9 | beatrice
# Processing Record 25 of Set 9 | krotoszyn
# Processing Record 26 of Set 9 | isangel
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | fort nelson
# Processing Record 29 of Set 9 | sibolga
# Processing Record 30 of Set 9 | coolum beach
# Processing Record 31 of Set 9 | callaway
# Processing Record 32 of Set 9 | srisailam
# Processing Record 33 of Set 9 | bac lieu
# Processing Record 34 of Set 9 | calabazar de sagua
# Processing Record 35 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 36 of Set 9 | saint-philippe
# Processing Record 37 of Set 9 | mufulira
# Processing Record 38 of Set 9 | jacqueville
# Processing Record 39 of Set 9 | sinnamary
# Processing Record 40 of Set 9 | kununurra
# Processing Record 41 of Set 9 | richards bay
# Processing Record 42 of Set 9 | podbelsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | zarechnyy
# Processing Record 45 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 9 | zambezi
# Processing Record 47 of Set 9 | tongliao
# Processing Record 48 of Set 9 | ca mau
# Processing Record 49 of Set 9 | guarapuava
# Processing Record 0 of Set 10 | marienburg
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | honiara
# Processing Record 4 of Set 10 | aranos
# Processing Record 5 of Set 10 | san angelo
# Processing Record 6 of Set 10 | qianan
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | gornopravdinsk
# Processing Record 9 of Set 10 | sioux lookout
# Processing Record 10 of Set 10 | maun
# Processing Record 11 of Set 10 | vila franca do campo
# Processing Record 12 of Set 10 | simao
# Processing Record 13 of Set 10 | jijiga
# Processing Record 14 of Set 10 | cancuc
# Processing Record 15 of Set 10 | sotnikovo
# Processing Record 16 of Set 10 | sisimiut
# Processing Record 17 of Set 10 | pau
# Processing Record 18 of Set 10 | bourail
# Processing Record 19 of Set 10 | ukiah
# Processing Record 20 of Set 10 | hobyo
# Processing Record 21 of Set 10 | hamilton
# Processing Record 22 of Set 10 | codrington
# Processing Record 23 of Set 10 | talnakh
# Processing Record 24 of Set 10 | cody
# Processing Record 25 of Set 10 | kyabram
# Processing Record 26 of Set 10 | amapa
# Processing Record 27 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 10 | scottsbluff
# Processing Record 29 of Set 10 | zholymbet
# Processing Record 30 of Set 10 | maceio
# Processing Record 31 of Set 10 | mackay
# Processing Record 32 of Set 10 | riviere-au-renard
# Processing Record 33 of Set 10 | santa cruz
# Processing Record 34 of Set 10 | karlshamn
# Processing Record 35 of Set 10 | atambua
# Processing Record 36 of Set 10 | kudahuvadhoo
# Processing Record 37 of Set 10 | indramayu
# Processing Record 38 of Set 10 | livno
# Processing Record 39 of Set 10 | saint-michel-des-saints
# Processing Record 40 of Set 10 | verkhnyaya inta
# Processing Record 41 of Set 10 | george town
# Processing Record 42 of Set 10 | cayenne
# Processing Record 43 of Set 10 | college
# Processing Record 44 of Set 10 | guilin
# Processing Record 45 of Set 10 | kahului
# Processing Record 46 of Set 10 | mancio lima
# Processing Record 47 of Set 10 | balkanabat
# Processing Record 48 of Set 10 | mahanoro
# Processing Record 49 of Set 10 | kashirskoye
# Processing Record 0 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 11 | xichang
# Processing Record 2 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 3 of Set 11 | vuktyl
# Processing Record 4 of Set 11 | piacabucu
# Processing Record 5 of Set 11 | clarence town
# Processing Record 6 of Set 11 | contai
# Processing Record 7 of Set 11 | kemijarvi
# Processing Record 8 of Set 11 | gorin
# Processing Record 9 of Set 11 | mercedes
# Processing Record 10 of Set 11 | seymchan
# Processing Record 11 of Set 11 | pontianak
# Processing Record 12 of Set 11 | porto novo
# Processing Record 13 of Set 11 | yaan
# Processing Record 14 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 11 | henties bay
# Processing Record 17 of Set 11 | afsin
# Processing Record 18 of Set 11 | agadir
# Processing Record 19 of Set 11 | guozhen
# Processing Record 20 of Set 11 | pascagoula
# Processing Record 21 of Set 11 | majene
# Processing Record 22 of Set 11 | yulara
# Processing Record 23 of Set 11 | billings
# Processing Record 24 of Set 11 | las vegas
# Processing Record 25 of Set 11 | port macquarie
# Processing Record 26 of Set 11 | lethem
# Processing Record 27 of Set 11 | watsa
# Processing Record 28 of Set 11 | griffith
# Processing Record 29 of Set 11 | tabas
# Processing Record 30 of Set 11 | bani walid
# Processing Record 31 of Set 11 | yucca valley
# Processing Record 32 of Set 11 | strelka
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | pochutla
# Processing Record 35 of Set 11 | xushan
# Processing Record 36 of Set 11 | borogontsy
# Processing Record 37 of Set 11 | sinop
# Processing Record 38 of Set 11 | orsha
# Processing Record 39 of Set 11 | erdenet
# Processing Record 40 of Set 11 | katsuura
# Processing Record 41 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 11 | iskateley
# Processing Record 43 of Set 11 | ishigaki
# Processing Record 44 of Set 11 | palmer
# Processing Record 45 of Set 11 | mandera
# Processing Record 46 of Set 11 | tigil
# Processing Record 47 of Set 11 | darnah
# Processing Record 48 of Set 11 | hambantota
# Processing Record 49 of Set 11 | jeffersontown
# Processing Record 0 of Set 12 | nantucket
# Processing Record 1 of Set 12 | laguna
# Processing Record 2 of Set 12 | akyab
# Processing Record 3 of Set 12 | usakos
# Processing Record 4 of Set 12 | constitucion
# Processing Record 5 of Set 12 | eureka
# Processing Record 6 of Set 12 | northam
# Processing Record 7 of Set 12 | coquimbo
# Processing Record 8 of Set 12 | bandundu
# Processing Record 9 of Set 12 | shuangcheng
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | sur
# Processing Record 12 of Set 12 | altay
# Processing Record 13 of Set 12 | tamworth
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | linxia
# Processing Record 16 of Set 12 | altamont
# Processing Record 17 of Set 12 | george
# Processing Record 18 of Set 12 | kuznechikha
# Processing Record 19 of Set 12 | mananjary
# Processing Record 20 of Set 12 | qostanay
# Processing Record 21 of Set 12 | faxinal
# Processing Record 22 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 12 | kutum
# Processing Record 24 of Set 12 | awbari
# Processing Record 25 of Set 12 | shaunavon
# Processing Record 26 of Set 12 | chicama
# Processing Record 27 of Set 12 | mahibadhoo
# Processing Record 28 of Set 12 | heishan
# Processing Record 29 of Set 12 | guiratinga
# Processing Record 30 of Set 12 | dandong
# Processing Record 31 of Set 12 | hirado
# Processing Record 32 of Set 12 | lorengau
# Processing Record 33 of Set 12 | maarianhamina
# Processing Record 34 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 35 of Set 12 | mumford
# Processing Record 36 of Set 12 | ferme-neuve
# Processing Record 37 of Set 12 | chute-aux-outardes
# Processing Record 38 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 12 | dwarahat
# Processing Record 40 of Set 12 | la ronge
# Processing Record 41 of Set 12 | rio grande
# Processing Record 42 of Set 12 | west wendover
# Processing Record 43 of Set 12 | llanes
# Processing Record 44 of Set 12 | gazli
# Processing Record 45 of Set 12 | camacha
# Processing Record 46 of Set 12 | niksic
# Processing Record 47 of Set 12 | fukue
# Processing Record 48 of Set 12 | volodarka
# Processing Record 49 of Set 12 | mehamn
# Processing Record 0 of Set 13 | yeppoon
# Processing Record 1 of Set 13 | zhuanghe
# Processing Record 2 of Set 13 | waverly
# Processing Record 3 of Set 13 | torrington
# Processing Record 4 of Set 13 | susanville
# Processing Record 5 of Set 13 | holguin
# Processing Record 6 of Set 13 | khani
# Processing Record 7 of Set 13 | hasanabad
# Processing Record 8 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 13 | marfino
# Processing Record 10 of Set 13 | olinda
# Processing Record 11 of Set 13 | vostok
# Processing Record 12 of Set 13 | sagar
# Processing Record 13 of Set 13 | phalaborwa
# Processing Record 14 of Set 13 | pemba
# Processing Record 15 of Set 13 | bunia
# Processing Record 16 of Set 13 | matagami
# Processing Record 17 of Set 13 | srednekolymsk
# Processing Record 18 of Set 13 | coralville
# Processing Record 19 of Set 13 | antofagasta
# Processing Record 20 of Set 13 | kalmunai
# Processing Record 21 of Set 13 | kommunisticheskiy
# Processing Record 22 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 23 of Set 13 | berdigestyakh
# Processing Record 24 of Set 13 | otjimbingwe
# Processing Record 25 of Set 13 | calama
# Processing Record 26 of Set 13 | zapolyarnyy
# Processing Record 27 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 28 of Set 13 | shunyi
# Processing Record 29 of Set 13 | sechura
# Processing Record 30 of Set 13 | itupiranga
# Processing Record 31 of Set 13 | lompoc
# Processing Record 32 of Set 13 | burgeo
# Processing Record 33 of Set 13 | barcelos
# Processing Record 34 of Set 13 | quimper
# Processing Record 35 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 13 | helmsdale
# Processing Record 37 of Set 13 | rio tuba
# Processing Record 38 of Set 13 | sabha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
# city_data_df = pd.DataFrame({"City": cities, 
#                           "Lat": city_lat, 
#                           "Lng": city_lng, 
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  port blair  11.6667   92.7500     77.04        83          40        2.30
# 1  butaritari   3.0707  172.7902     80.49        79          78       18.45
# 2     ushuaia -54.8000  -68.3000     58.66        58          75       14.97
# 3   jamestown  42.0970  -79.2353     22.59        72          62        1.01
# 4      atuona  -9.8000 -139.0333     78.67        77          80       15.99
#
#   Country        Date
# 0      IN  1675295929
# 1      KI  1675295929
# 2      AR  1675295676
# 3      US  1675295930
# 4      PF  1675295931

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port blair  11.6667   92.7500     77.04        83          40
# 1        butaritari   3.0707  172.7902     80.49        79          78
# 2           ushuaia -54.8000  -68.3000     58.66        58          75
# 3         jamestown  42.0970  -79.2353     22.59        72          62
# 4            atuona  -9.8000 -139.0333     78.67        77          80
#
#          Wind Speed Country        Date
# City_ID
# 0              2.30      IN  1675295929
# 1             18.45      KI  1675295929
# 2             14.97      AR  1675295676
# 3              1.01      US  1675295930
# 4             15.99      PF  1675295931

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker='o', facecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitute Vs. Temperature")
plt.xlabel("Latitute")
plt.ylabel("Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker='o', facecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitute Vs. Humidity")
plt.xlabel("Latitute")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker='o', facecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitute Vs. Cloudiness")
plt.xlabel("Latitute")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker='o', facecolors="blue", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitute Vs. Wind Speed")
plt.xlabel("Latitute")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
corr=round(city_data_df(city_data_df['Lat'],city_data_df['Humidity'])[0],2)
print(f"The correlation between Latitude and the Humidity is {corr}")
model = city_data_df.linregress(city_data_df['Lat'],city_data_df['Humidity'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/m2/l07jxc6d0tg0q6161pf7rvbc0000gn/T/ipykernel_71166/3964054454.py in <module>
#       1 # Define a function to create Linear Regression plots
# ----> 2 corr=round(city_data_df(city_data_df['Lat'],city_data_df['Humidity'])[0],2)
#       3 print(f"The correlation between Latitude and the Humidity is {corr}")
#       4 model = city_data_df.linregress(city_data_df['Lat'],city_data_df['Humidity'])
#
# TypeError: 'DataFrame' object is not callable

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
